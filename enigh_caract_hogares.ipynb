# %% [markdown]
# <a href="https://colab.research.google.com/github/zenyonki/enigh_caract_hogares/blob/main/enigh_caract_hogares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
indice_tablas = pd.read_csv('/content/0_indice_tablas_enigh_2022_ns.csv', encoding='latin-1')
indice_tablas.reset_index(drop=True, inplace=True)
indice_tablas
# Out:
#    Encuesta Nacional de Ingresos y Gastos de los Hogares 2022 Nueva Serie\t  \
# 0                                                  \t
# 1                 Nombre de archivo\tTítulo de Tablas
# 2              conjunto_de_datos_agro_enigh_2022_ns\t
# 3         conjunto_de_datos_agroconsumo_enigh_2022_ns
# 4           conjunto_de_datos_agrogasto_enigh_2022_ns
# 5       conjunto_de_datos_agroproductos_enigh_2022_ns
# 6   conjunto_de_datos_concentradohogar_enigh_2022_...
# 7       conjunto_de_datos_erogaciones_enigh_2022_ns\t
# 8       conjunto_de_datos_gastoshogar_enigh_2022_ns\t
# 9     conjunto_de_datos_gastospersona_enigh_2022_ns\t
# 10    conjunto_de_datos_gastotarjetas_enigh_2022_ns\t
# 11          conjunto_de_datos_hogares_enigh_2022_ns\t
# 12         conjunto_de_datos_ingresos_enigh_2022_ns\t
# 13       conjunto_de_datos_ingresos_jcf_enigh_2022_ns
# 14           conjunto_de_datos_noagro_enigh_2022_ns\t
# 15     conjunto_de_datos_noagroimportes_enigh_2022_ns
# 16          conjunto_de_datos_poblacion_enigh_2022_ns
# 17         conjunto_de_datos_trabajos_enigh_2022_ns\t
# 18        conjunto_de_datos_viviendas_enigh_2022_ns\t
#
#                                            Unnamed: 1
# 0                                                 NaN
# 1                                                 NaN
# 2               Negocios agropecuarios de los hogares
# 3   Destino, cantidad y valor de los productos del...
# 4             Gasto que realiza el negocio del Hogar
# 5      Productos de los negocios agrícolas del hogar
# 6                     Principales variables por hogar
# 7                    Erogaciones de capital por hogar
# 8                               Gastos en los hogares
# 9    Gastos realizados en el hogar a nivel integrante
# 10  Gastos realizados por el hogar y que fueron cu...
# 11  Características de los hogares que habitan los...
# 12  Ingresos y percepciones financieras y de capit...
# 13  Ingresos del programa Jóvenes Construyendo el ...
# 14           Negocios no agropecuarios de los hogares
# 15  Importe de los productos de los negocios no ag...
# 16  \tCaracterísticas sociodemográficas de los int...
# 17  Condición de actividad de los integrantes del ...
# 18  Características de las viviendas que habitan l...

# %%
caract_hogares = pd.read_csv('/content/conjunto_de_datos_viviendas_enigh2022_ns.csv', encoding='utf-8-sig')
caract_hogares.reset_index(drop=True, inplace=True)
caract_hogares.sample(10)
# Out:
#          folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 66502  2403625316        1          8          10         3         40
# 13029   503013804        1          8          10         3
# 80724  3001719805        1          8          10         2         31
# 20203   760638016        1          8           3         2         30
# 51869  1904981404        1          8          10         3         35
# 31861  1108229601        1          8           4         2         30
# 44301  1600412204        1          8          10         2         39
# 44824  1603310007        1          8          10         3         25
# 70215  2504571724        1          8          10         3         25
# 39210  1409095701        1          8          10         3         20
#
#       antigua_ne  cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# 66502                  1          2           1  ...        0        1
# 13029          1       1          2           3  ...        2        3
# 80724                  1          2           3  ...        2        4
# 20203                  1          2           2  ...        2        2
# 51869                  1          2           4  ...        2        3
# 31861                  1          2           1  ...        1        1
# 44301                  1          2           3  ...        4        5
# 44824                  1          2           3  ...        1        3
# 70215                  1          2           3  ...        2        3
# 39210                  1          2           2  ...        0        1
#
#       tot_hog  ubica_geo tam_loc est_socio est_dis   upm factor procaptar
# 66502       1      24008       3         2     396  7779    349         0
# 13029       1       5030       1         2      57  1586    338         0
# 80724       1      30087       1         2     503  9464   1035         0
# 20203       1       7019       4         1     116  2444    746         0
# 51869       1      19039       1         2     305  6129    786         0
# 31861       1      11007       3         2     182  4000    775         0
# 44301       1      16053       1         3     257  5241    570         0
# 44824       1      16050       2         3     266  5332    666         0
# 70215       1      25018       2         3     414  8243    161         0
# 39210       1      14120       1         4     220  4719   1357         0
#
# [10 rows x 64 columns]

# %%
caract_hogares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88823 entries, 0 to 88822
# Data columns (total 64 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   folioviv     88823 non-null  int64
#  1   tipo_viv     88823 non-null  object
#  2   mat_pared    88823 non-null  int64
#  3   mat_techos   88823 non-null  int64
#  4   mat_pisos    88823 non-null  object
#  5   antiguedad   88823 non-null  object
#  6   antigua_ne   88823 non-null  object
#  7   cocina       88823 non-null  int64
#  8   cocina_dor   88823 non-null  object
#  9   cuart_dorm   88823 non-null  int64
#  10  num_cuarto   88823 non-null  int64
#  11  disp_agua    88823 non-null  int64
#  12  dotac_agua   88823 non-null  object
#  13  excusado     88823 non-null  int64
#  14  uso_compar   88823 non-null  object
#  15  sanit_agua   88823 non-null  object
#  16  biodigest    88823 non-null  object
#  17  bano_comp    88823 non-null  object
#  18  bano_excus   88823 non-null  object
#  19  bano_regad   88823 non-null  object
#  20  drenaje      88823 non-null  int64
#  21  disp_elect   88823 non-null  int64
#  22  focos_inca   88823 non-null  object
#  23  focos_ahor   88823 non-null  object
#  24  combustible  88823 non-null  object
#  25  estufa_chi   88823 non-null  object
#  26  eli_basura   88823 non-null  int64
#  27  tenencia     88823 non-null  int64
#  28  renta        88823 non-null  object
#  29  estim_pago   88823 non-null  object
#  30  pago_viv     88823 non-null  object
#  31  pago_mesp    88823 non-null  object
#  32  tipo_adqui   88823 non-null  object
#  33  viv_usada    88823 non-null  object
#  34  tipo_finan   88823 non-null  object
#  35  num_dueno1   88823 non-null  object
#  36  hog_dueno1   88823 non-null  object
#  37  num_dueno2   88823 non-null  object
#  38  hog_dueno2   88823 non-null  object
#  39  escrituras   88823 non-null  object
#  40  lavadero     88823 non-null  int64
#  41  fregadero    88823 non-null  int64
#  42  regadera     88823 non-null  int64
#  43  tinaco_azo   88823 non-null  int64
#  44  cisterna     88823 non-null  int64
#  45  pileta       88823 non-null  int64
#  46  calent_sol   88823 non-null  int64
#  47  calent_gas   88823 non-null  int64
#  48  medidor_luz  88823 non-null  int64
#  49  bomba_agua   88823 non-null  int64
#  50  tanque_gas   88823 non-null  int64
#  51  aire_acond   88823 non-null  int64
#  52  calefacc     88823 non-null  int64
#  53  tot_resid    88823 non-null  int64
#  54  tot_hom      88823 non-null  int64
#  55  tot_muj      88823 non-null  int64
#  56  tot_hog      88823 non-null  int64
#  57  ubica_geo    88823 non-null  int64
#  58  tam_loc      88823 non-null  int64
#  59  est_socio    88823 non-null  int64
#  60  est_dis      88823 non-null  int64
#  61  upm          88823 non-null  int64
#  62  factor       88823 non-null  int64
#  63  procaptar    88823 non-null  int64
# dtypes: int64(36), object(28)
# memory usage: 43.4+ MB

# %%
caract_hogares['folioviv'] = caract_hogares['folioviv'].astype(str)
caract_hogares['folioviv'] = caract_hogares['folioviv'].apply(
    lambda x: '0' + x if len(x) == 9 else x
)
caract_hogares['folioviv'].str.len().value_counts()
# Out:
# folioviv
# 10    88823
# Name: count, dtype: int64

# %%
caract_hogares.sample(10)
# Out:
#          folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 72529  2604895705        1          8          10         3         20
# 8558   0360004605        1          8          10         2         20
# 406    0100697304        1          8          10         3         30
# 87355  3201678612        1          8          10         3         50
# 11774  0500293406        1          8          10         3         20
# 25965  0905996306        1          8          10         3         40
# 27025  0918522805        1          8          10         3         70
# 61786  2260199302        1          8          10         3         34
# 44835  1603310521        1          8          10         2         16
# 11914  0500577701        1          8          10         3
#
#       antigua_ne  cocina cocina_dor  cuart_dorm  ...  tot_hom  tot_muj  \
# 72529                  1          2           3  ...        2        4
# 8558                   1          2           1  ...        2        2
# 406                    1          2           3  ...        2        0
# 87355                  1          2           3  ...        1        2
# 11774                  1          2           3  ...        1        1
# 25965                  1          2           3  ...        1        1
# 27025                  1          2           1  ...        1        1
# 61786                  1          2           1  ...        0        1
# 44835                  2                      3  ...        2        1
# 11914          1       1          2           1  ...        0        1
#
#       tot_hog  ubica_geo tam_loc est_socio est_dis    upm factor procaptar
# 72529       1      26055       1         3     430   8529    530         0
# 8558        1       3001       4         2      43    982     55         0
# 406         1       1001       1         3       2     91    193         0
# 87355       1      32048       2         3     556  10159    143         0
# 11774       1       5002       1         2      77   1327    223         0
# 25965       1       9006       1         3     141   3177   1070         0
# 27025       1       9015       1         4     142   3390   1391         0
# 61786       1      22016       4         2     370   7153    131         0
# 44835       1      16050       2         3     266   5332    666         0
# 11914       1       5018       1         3      70   1356    187         0
#
# [10 rows x 64 columns]

# %%
caract_hogares['entidad'] = caract_hogares['folioviv'].str[:2].map(entidades_mexico)
caract_hogares.head(10)
# Out:
#      folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad antigua_ne  \
# 0  0100005002        1          8          10         3         30
# 1  0100005003        1          8          10         3         15
# 2  0100005004        1          8          10         3         25
# 3  0100012002        1          8          10         3         50
# 4  0100012004        1          8          10         3         45
# 5  0100012006        1          8          10         3         25
# 6  0100019301        1          8          10         3         48
# 7  0100019302        1          8          10         3         36
# 8  0100019303        1          8          10         3         35
# 9  0100019304        1          8          10         3          1
#
#    cocina cocina_dor  cuart_dorm  ...  tot_muj  tot_hog ubica_geo  tam_loc  \
# 0       1          2           2  ...        3        1      1001        1
# 1       1          2           3  ...        1        1      1001        1
# 2       1          2           3  ...        1        1      1001        1
# 3       1          2           4  ...        2        2      1001        1
# 4       1          2           3  ...        2        1      1001        1
# 5       1          2           2  ...        2        1      1001        1
# 6       1          2           5  ...        1        1      1001        1
# 7       1          2           4  ...        2        1      1001        1
# 8       1          2           3  ...        1        1      1001        1
# 9       1          2           3  ...        4        1      1001        1
#
#   est_socio est_dis upm factor procaptar         entidad
# 0         4       3   1    206         0  Aguascalientes
# 1         4       3   1    206         0  Aguascalientes
# 2         4       3   1    206         0  Aguascalientes
# 3         3       2   2    167         0  Aguascalientes
# 4         3       2   2    167         0  Aguascalientes
# 5         3       2   2    167         0  Aguascalientes
# 6         4       3   3    212         0  Aguascalientes
# 7         4       3   3    212         0  Aguascalientes
# 8         4       3   3    212         0  Aguascalientes
# 9         4       3   3    212         0  Aguascalientes
#
# [10 rows x 65 columns]

# %%
columnas_a_eliminar = caract_hogares.columns[[0, 6, 8, 9, 10, 12, 17, 18, 19, 22, 23, 28, 29, 30, 31, 35, 36, 37, 38, 53, 54, 55, 56, 59, 60, 61, 62, 63]]
caract_hogares = caract_hogares.drop(columns=columnas_a_eliminar)
caract_hogares.head()
# Out:
#   tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  cocina  disp_agua  \
# 0        1          8          10         3         30       1          1
# 1        1          8          10         3         15       1          1
# 2        1          8          10         3         25       1          1
# 3        1          8          10         3         50       1          1
# 4        1          8          10         3         45       1          1
#
#    excusado uso_compar sanit_agua  ... calent_sol  calent_gas  medidor_luz  \
# 0         1          2          1  ...          1           1            1
# 1         1          2          1  ...          1           1            1
# 2         1          2          1  ...          1           1            1
# 3         1          2          1  ...          1           1            1
# 4         1          2          1  ...          2           1            1
#
#   bomba_agua tanque_gas  aire_acond  calefacc ubica_geo tam_loc  \
# 0          1          2           2         2      1001       1
# 1          1          1           2         2      1001       1
# 2          1          2           2         2      1001       1
# 3          1          2           2         2      1001       1
# 4          1          2           2         2      1001       1
#
#           entidad
# 0  Aguascalientes
# 1  Aguascalientes
# 2  Aguascalientes
# 3  Aguascalientes
# 4  Aguascalientes
#
# [5 rows x 37 columns]

# %%
columnas = list(caract_hogares.columns)
columnas
# Out:
# ['tipo_viv',
#  'mat_pared',
#  'mat_techos',
#  'mat_pisos',
#  'antiguedad',
#  'cocina',
#  'disp_agua',
#  'excusado',
#  'uso_compar',
#  'sanit_agua',
#  'biodigest',
#  'drenaje',
#  'disp_elect',
#  'combustible',
#  'estufa_chi',
#  'eli_basura',
#  'tenencia',
#  'tipo_adqui',
#  'viv_usada',
#  'tipo_finan',
#  'escrituras',
#  'lavadero',
#  'fregadero',
#  'regadera',
#  'tinaco_azo',
#  'cisterna',
#  'pileta',
#  'calent_sol',
#  'calent_gas',
#  'medidor_luz',
#  'bomba_agua',
#  'tanque_gas',
#  'aire_acond',
#  'calefacc',
#  'ubica_geo',
#  'tam_loc',
#  'entidad']

# %%
# Diccionario de renombramiento
nuevos_nombres = {
    'tipo_viv': 'tipo_vivienda',
    'mat_pared': 'material_paredes',
    'mat_techos': 'material_techos',
    'mat_pisos': 'material_pisos',
    'antiguedad': 'antigüedad',
    'cocina': 'cocina',
    'disp_agua': 'disp_agua',
    'excusado': 'excusado',
    'uso_compar': 'uso_compartido',
    'sanit_agua': 'agua_sanitario',
    'biodigest': 'biodigestor',
    'drenaje': 'drenaje',
    'disp_elect': 'disp_electricidad',
    'combustible': 'combustible_cocina',
    'estufa_chi': 'estufa',
    'eli_basura': 'manejo_basura',
    'tenencia': 'tenencia',
    'tipo_adqui': 'tipo_adquisicion',
    'viv_usada': 'vivienda_usada',
    'tipo_finan': 'tipo_financiamiento',
    'escrituras': 'escrituras',
    'lavadero': 'lavadero',
    'fregadero': 'fregadero',
    'regadera': 'regadera',
    'tinaco_azo': 'tinaco',
    'cisterna': 'cisterna',
    'pileta': 'pileta',
    'calent_sol': 'calentador_solar',
    'calent_gas': 'calentador_gas',
    'medidor_luz': 'medidor_luz',
    'bomba_agua': 'bomba_agua',
    'tanque_gas': 'tanque_gas',
    'aire_acond': 'aire_acondicionado',
    'calefacc': 'calefacción',
    'ubica_geo': 'ubicacion_geografica',
    'tam_loc': 'tamano_localidad',
    'entidad': 'entidad'
}

caract_hogares = caract_hogares.rename(columns=nuevos_nombres)
caract_hogares.head()
# Out:
#   tipo_vivienda  material_paredes  material_techos material_pisos antigüedad  \
# 0             1                 8               10              3         30
# 1             1                 8               10              3         15
# 2             1                 8               10              3         25
# 3             1                 8               10              3         50
# 4             1                 8               10              3         45
#
#    cocina  disp_agua  excusado uso_compartido agua_sanitario  ...  \
# 0       1          1         1              2              1  ...
# 1       1          1         1              2              1  ...
# 2       1          1         1              2              1  ...
# 3       1          1         1              2              1  ...
# 4       1          1         1              2              1  ...
#
#   calentador_solar  calentador_gas  medidor_luz bomba_agua tanque_gas  \
# 0                1               1            1          1          2
# 1                1               1            1          1          1
# 2                1               1            1          1          2
# 3                1               1            1          1          2
# 4                2               1            1          1          2
#
#    aire_acondicionado  calefacción ubicacion_geografica tamano_localidad  \
# 0                   2            2                 1001                1
# 1                   2            2                 1001                1
# 2                   2            2                 1001                1
# 3                   2            2                 1001                1
# 4                   2            2                 1001                1
#
#           entidad
# 0  Aguascalientes
# 1  Aguascalientes
# 2  Aguascalientes
# 3  Aguascalientes
# 4  Aguascalientes
#
# [5 rows x 37 columns]

# %%
columnas_nuevas = list(caract_hogares.columns)
columnas_nuevas
# Out:
# ['tipo_vivienda',
#  'material_paredes',
#  'material_techos',
#  'material_pisos',
#  'antigüedad',
#  'cocina',
#  'disp_agua',
#  'excusado',
#  'uso_compartido',
#  'agua_sanitario',
#  'biodigestor',
#  'drenaje',
#  'disp_electricidad',
#  'combustible_cocina',
#  'estufa',
#  'manejo_basura',
#  'tenencia',
#  'tipo_adquisicion',
#  'vivienda_usada',
#  'tipo_financiamiento',
#  'escrituras',
#  'lavadero',
#  'fregadero',
#  'regadera',
#  'tinaco',
#  'cisterna',
#  'pileta',
#  'calentador_solar',
#  'calentador_gas',
#  'medidor_luz',
#  'bomba_agua',
#  'tanque_gas',
#  'aire_acondicionado',
#  'calefacción',
#  'ubicacion_geografica',
#  'tamano_localidad',
#  'entidad']

# %%
caract_hogares.to_csv("caract_hogares_limpio.csv", index=False, encoding='utf-8-sig')
